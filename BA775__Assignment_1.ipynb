# %% [markdown]
# <a href="https://colab.research.google.com/github/olaf-ys/Big-Query-GCP/blob/main/BA775__Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# ## Assignment 1 - BA775 (Fall 2023)
#
# Note that this assignment captures topics from classes 3 & 4. You should run your queries in BigQuery or a Vertex AI notebook and submit the answers with your code in the rationale box of Blackboard (under the Assessment tab). 50% of the grade comes from the rationale and the other 50% from the multiple-choice answers.

# %% [markdown]
# ### Question 1&2
#
# Using the following table (`bigquery-public-data.baseball.schedules`), which baseball game had the biggest attendance in 2016?

# %%
# %%bigquery --project=ba-775-olaf
# SELECT * FROM `bigquery-public-data.baseball.schedules` LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                  gameId  gameNumber  \
# 0  e14b6493-9e7f-404f-840a-8a680cc364bf           1
# 1  1f32b347-cbcb-4c31-a145-0e685306d168           1
# 2  0c2292d1-7398-48be-bf8e-b41dad5e1a43           1
# 3  8fbec734-a15a-42ab-8d51-60790de7750b           1
# 4  89e514d5-fbf5-4b9d-bdac-6ca45bfd18dd           1
#
#                                seasonId  year type dayNight duration  \
# 0  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     3:07
# 1  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     3:09
# 2  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     2:45
# 3  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     3:42
# 4  565de4be-dc80-4849-a7e1-54bc79156cc8  2016  REG        D     2:44
#
#    duration_minutes                            homeTeamId homeTeamName  \
# 0               187  03556285-bdbb-4576-a06d-42f71f46ddc5      Marlins
# 1               189  03556285-bdbb-4576-a06d-42f71f46ddc5      Marlins
# 2               165  12079497-e414-450a-8bf2-29f91de646bf       Braves
# 3               222  12079497-e414-450a-8bf2-29f91de646bf       Braves
# 4               164  2142e1ba-3b40-445c-b8bb-f1f8b1054220     Phillies
#
#                              awayTeamId awayTeamName  \
# 0  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 1  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 2  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 3  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
# 4  55714da8-fcaf-4574-8443-59bfb511a524         Cubs
#
#                   startTime  attendance  status                   created
# 0 2016-06-26 17:10:00+00:00       27318  closed 2016-10-06 06:25:15+00:00
# 1 2016-06-25 20:10:00+00:00       29457  closed 2016-10-06 06:25:15+00:00
# 2 2016-06-11 20:10:00+00:00       43114  closed 2016-10-06 06:25:15+00:00
# 3 2016-06-12 17:35:00+00:00       31625  closed 2016-10-06 06:25:15+00:00
# 4 2016-06-08 17:05:00+00:00       28650  closed 2016-10-06 06:25:15+00:00

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select homeTeamName, year, sum(attendance) as total_attendance from `bigquery-public-data.baseball.schedules`
where year = 2016
group by homeTeamName, year
order by total_attendance desc
limit 3
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#   homeTeamName  year  total_attendance
# 0      Dodgers  2016           3703312
# 1    Cardinals  2016           3444490
# 2    Blue Jays  2016           3392309

# %% [markdown]
# ### Question 3&4
#
# In 2016, which team played the longest games at home on average?
#
# Hint: You will need to take the average `duration_minutes` for each `homeTeamName`. This can be achieved by a `GROUP BY` and then an `ORDER BY`.

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select homeTeamName, year, avg(duration_minutes) as avg_duration from `bigquery-public-data.baseball.schedules`
where year = 2016
group by homeTeamName, year
order by avg_duration desc
limit 3
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    homeTeamName  year  avg_duration
# 0  Diamondbacks  2016    197.111111
# 1       Red Sox  2016    196.012346
# 2       Rockies  2016    193.629630

# %% [markdown]
# ---
# ---
# The remaining questions refer to table `bigquery-public-data.austin_bikeshare.bikeshare_trips`.

# %%
# %%bigquery --project=ba-775-olaf
# SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips` LIMIT 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    trip_id subscriber_type bike_id bike_type                start_time  \
# 0  9150090         Walk Up     385   classic 2016-03-16 14:32:19+00:00
# 1  9284953   Annual Member     625   classic 2016-03-25 16:53:59+00:00
# 2  9209168         Local30     890   classic 2016-03-20 12:21:42+00:00
# 3  9271350        Local365     554   classic 2016-03-24 12:57:56+00:00
# 4  9134875         Walk Up     871   classic 2016-03-15 16:43:34+00:00
#
#    start_station_id               start_station_name end_station_id  \
# 0              2544        East 6th & Pedernales St.           2538
# 1              2541  State Capitol @ 14th & Colorado           2538
# 2              2541  State Capitol @ 14th & Colorado           2538
# 3              2541  State Capitol @ 14th & Colorado           2538
# 4              2541  State Capitol @ 14th & Colorado           2538
#
#                   end_station_name  duration_minutes
# 0  Bullock Museum @ Congress & MLK                23
# 1  Bullock Museum @ Congress & MLK                15
# 2  Bullock Museum @ Congress & MLK                25
# 3  Bullock Museum @ Congress & MLK                 6
# 4  Bullock Museum @ Congress & MLK                25

# %% [markdown]
# ### Question 5&6
#
# How many distinct and valid station IDs are in this table? Valid station IDs are integer numbers.
#
# **Note1:** notice that we are looking for valid station IDs, meaning that any station ID that is missing (is null) should be excluded.
#
# **Note2:** the question doesn't specify `start_station_id` or `end_station_id` and refers to all the station IDs. You would need to use a UNION to merge them all.
#
# **Note3:** `start_station_id` is listed as INT but `end_station_id` is STR. To do a UNION, you must have all of the columns in the same format and the same data type. Convert `start_station_id` to STR: I.e, `CAST(start_station_id AS STRING)`
#
# **Hint:** some records have `end_station_id` as `'Event'`. Since these do not qualify as valid station IDs we will have to exclude them.

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select count(distinct station_id) as valid_station_id from
(
select cast(start_station_id as string) as station_id from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
where start_station_id is not null
union distinct
select end_station_id as station_id from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
where end_station_id is not null
and end_station_id <> 'Event'
)
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    valid_station_id
# 0               106

# %% [markdown]
# ### Question 7&8
# Which station has the highest number of trips that start from and end at that station?

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select
count(trip_id) as number_of_trip, cast(start_station_id as string) as station_id
from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
where cast(start_station_id as string) = end_station_id
group by station_id
order by number_of_trip desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      number_of_trip station_id
# 0             18343       3798
# 1             17683       2575
# 2             15009       2574
# 3             14244       2707
# 4              8996       3377
# ..              ...        ...
# 100              50       1006
# 101              45       3381
# 102              12       1008
# 103               8       3456
# 104               1       1001
#
# [105 rows x 2 columns]

# %% [markdown]
# ### Question 9&10
# Which station is the most popular destination?

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select end_station_id, count(end_station_id) as end_station_counts
from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
group by end_station_id
order by end_station_counts desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     end_station_id  end_station_counts
# 0             3798              151720
# 1             2498               72392
# 2             2575               58220
# 3             2707               54984
# 4             2547               53814
# ..             ...                 ...
# 103           1008                 257
# 104          Event                 119
# 105           1001                  15
# 106           7637                  11
# 107           None                   0
#
# [108 rows x 2 columns]

# %% [markdown]
# ### Question 11&12
# How many different types of subscribers appear in this dataset?

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select count(distinct subscriber_type) as number_of_types
from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    number_of_types
# 0               60

# %% [markdown]
# ### Question 13&14
# Which one is by far the most popular subscriber plan?

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select count(subscriber_type) as number_of_types, subscriber_type
from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
group by subscriber_type
order by number_of_types desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     number_of_types                            subscriber_type
# 0            366023                                   Local365
# 1            305918                         Student Membership
# 2            289099                    U.T. Student Membership
# 3            272264                       24 Hour Walk Up Pass
# 4            260044                                    Walk Up
# ..              ...                                        ...
# 56                2  Membership: pay once, one-year commitment
# 57                1               Heartland Pass (Monthly Pay)
# 58                1                         24-Hour Membership
# 59                1                                 RESTRICTED
# 60                0                                       None
#
# [61 rows x 2 columns]

# %% [markdown]
# ### Question 15&16
# How many bike rides are in this dataset?

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select count(distinct trip_id)
from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
where bike_id is not null
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        f0_
# 0  2047235

# %% [markdown]
# ### Question 17&18
# Which month has been the busiest in 2023 so far?
#
# Hint: Use the EXTRACT function to extract the date components. For more help, go to the documentation: https://cloud.google.com/bigquery/docs/reference/standard-sql/date_functions

# %%
# Your answer goes here
# %%bigquery --project=ba-775-olaf
select extract(year from start_time) as year, extract(month from start_time) as month, count(distinct trip_id) as number_of_trips
from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
where extract(year from start_time) = 2023
group by year, month
order by number_of_trips desc
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    year  month  number_of_trips
# 0  2023      9            35320
# 1  2023      4            27621
# 2  2023      3            27205
# 3  2023      1            22052
# 4  2023      8            20189
# 5  2023      2            18739
# 6  2023      5            17461
# 7  2023      7            16460
# 8  2023      6            16144
